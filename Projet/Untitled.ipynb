# %%
from __future__ import division, print_function, unicode_literals

# imports
import numpy as np
import os
import pandas as pd

# stabilité du notebook d'une exécution à l'autre
np.random.seed(42)

# ignorer les warnings inutiles (voir SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")


general_data = pd.read_csv("dataset/general_data.csv")
employee_survey_data = pd.read_csv("dataset/employee_survey_data.csv")
manager_survey_data = pd.read_csv("dataset/manager_survey_data.csv")
out_time = pd.read_csv("dataset/out_time.csv")
in_time = pd.read_csv("dataset/in_time.csv")

# %%
for i in general_data:
    for j in i:
        print(i)
        if type(j) == "<class 'str'>":
            print("str")
# Out:
# Age
# Age
# Age
# Attrition
# Attrition
# Attrition
# Attrition
# Attrition
# Attrition
# Attrition
# Attrition
# Attrition
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# BusinessTravel
# Department
# Department
# Department
# Department
# Department
# Department
# Department
# Department
# Department
# Department
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# DistanceFromHome
# Education
# Education
# Education
# Education
# Education
# Education
# Education
# Education
# Education
# EducationField
# EducationField
# EducationField
# EducationField
# EducationField
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

housing["a_deviner"] = np.ceil(housing["truc_a_prendre"]/1.5)
housing["a_deviner"].where(housing["a_deviner"] < 5, 5.0, inplace=True) # replace where false

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(housing, housing["a_deviner"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

for set_ in (strat_train_set, strat_test_set):
    set_.drop("a_deviner", axis=1, inplace=True)

housing = strat_train_set.copy()
# Out:
# 0       51
# 1       31
# 2       32
# 3       38
# 4       32
#         ..
# 4405    42
# 4406    29
# 4407    25
# 4408    42
# 4409    40
# Name: Age, Length: 4410, dtype: int64
